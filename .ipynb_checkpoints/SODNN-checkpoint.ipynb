# %%
import os
import pandas as pd
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np




class CustomDataset(Dataset):
    def __init__(self):
        self.lc_file = './NN Stuff/Lightcurves.csv'
        self.label_path = './NN Stuff/Labels.csv'
        self.lightcurves = pd.read_csv(self.lc_file,header=None)
        self.labels = pd.read_csv(self.label_path,header=None)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        lightcurvetemp = self.lightcurves[idx,:].values
        lightcurvetemp = torch.from_numpy(lightcurve)
        lightcurve = torch.zeros(len(lightcurvetemp))
        count = 0
        for value in lightcurvetemp:
            lightcurve[count] = float(value)
            count = count + 1
        lightcurve = lightcurve.unsqueeze(0).unsqueeze(0)
        labeltemp = self.labels.iloc[idx,:].values
        labeltemp = torch.from_numpy(label)
        label = torch.zeros(len(labeltemp))
        count = 0
        for value in labeltemp:
            label[count] = float(value)
            count = count + 1
        label = label.unsqueeze(0).unsqueeze(0)
        return lightcurve, label

trainingset = CustomDataset()
print(trainingset)
trainingloader = DataLoader(trainingset,batch_size=20,shuffle=True)
print(trainingloader)
    #train_dataloader = DataLoader(trainingset,b

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1,out_channels=64,kernel_size=5,padding=2)
        self.conv2 = nn.Conv1d(in_channels=64,out_channels=64,kernel_size=5,padding=2)
        self.fc1 = nn.Linear(1152,100)
        self.fc2 = nn.Linear(100,2)
        self.pool = nn.MaxPool1d(kernel_size=4)
        self.softmax = nn.Softmax(dim=0)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.softmax(x)
        return x


net = Net()
print(net)
# Out:
# Net(
#   (conv1): Conv1d(1, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#   (conv2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#   (fc1): Linear(in_features=1152, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=2, bias=True)
#   (pool): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (softmax): Softmax(dim=0)
# )

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
 
headers = ['# Time', 'MAG']

df = pd.read_csv('./RB/file.csv', usecols = ['# Time','MAG_err'])

df.set_index('# Time').plot()

plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


RBPATH = './RB2/'
DEBPATH = './DEB2/'

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
 
headers = ['# Time', 'MAG']

#df = pd.read_csv('./RB/file.csv', usecols = ['# Time','MAG_err'])

#df.set_index('# Time').plot()

#plt.show()

filenames = os.listdir(RBPATH)
for file in filenames: 
    df = pd.read_csv(RBPATH + file, usecols = ['# Time','MAG_err'],index_col='# Time')
    plt.plot(df, color ='blue')
    #df.set_index('# Time').plot()
    #df=df[['# Time','MAG_err']]
    #df.to_csv(rb2PATH + file, index=False)
    #print(df)
filenames2=os.listdir(DEBPATH)
for file in filenames2:
    df=pd.read_csv(DEBPATH + file, usecols = ['# Time','MAG_err'],index_col='# Time')
    plt.plot(df, color='red')
plt.ylabel("Magnitude")
plt.xlabel("Time")
plt.xlim([0,1250])
plt.title("Training set data")
plt.plot([], [], ' ', label="(blue)Rocket Body", color='blue')
plt.plot([], [], ' ', label="(red)DEB", color='red')
plt.legend(loc="upper right")
#leg = plt.get_legend()
#leg.legendHandles[0].set_color('red')
#leg.legendHandles[1].set_color('yellow')

plt.show()
